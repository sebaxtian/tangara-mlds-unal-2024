# %%
import os
from dotenv import load_dotenv

# Explicitly providing path to '.env'
from pathlib import Path  # Python 3.6+ only
# Load .env variables
_ = load_dotenv(dotenv_path=f"{Path().resolve().parents[0]}/.env")

# with the new api
from importnb import imports
with imports("ipynb"):
    from utils import to_timestamp, df_data_sensors, df_to_csv, df_from_csv, to_file_name

# %%
# Start Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
START_ISO8601_DATETIME = os.getenv("START_ISO8601_DATETIME", None)
# End Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
END_ISO8601_DATETIME = os.getenv("END_ISO8601_DATETIME", None)

# %% [markdown]
# ## Tangaras

# %%
file_name = to_file_name("tangaras", START_ISO8601_DATETIME, END_ISO8601_DATETIME)
file_name
# Out:
# 2024-09-20 18:20:52.090 | DEBUG    | utils:to_file_name:448 - Run to_file_name:
# 2024-09-20 18:20:52.091 | DEBUG    | utils:to_file_name:449 - File Name: tangaras_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv
# 'tangaras_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv'

# %%
# Tangaras from CSV
df_tangaras = df_from_csv(file_name, dtindex=False)
print(f"Total Tangara Sensors: {len(df_tangaras)}")

df_tangaras
# Out:
# 2024-09-20 18:20:52.111 | DEBUG    | utils:df_from_csv:263 - Run df_from_csv:
# 2024-09-20 18:20:52.111 | DEBUG    | utils:df_from_csv:264 - Load DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-mlds-unal-2024/src/tangara/data/0_raw/tangaras_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv
# Total Tangara Sensors: 38
#               ID  GEOHASH              MAC  \
# 0   TANGARA_B7BE  d29e6de  D29ESP32DE0B7BE
# 1   TANGARA_C752  d29e6de  D29ESP32DE0C752
# 2   TANGARA_A682  d29e6de  D29ESP32DE3A682
# 3   TANGARA_ADD6  d29e6de  D29ESP32DE3ADD6
# 4   TANGARA_B9CA  d29e6de  D29ESP32DE3B9CA
# 5   TANGARA_BC5A  d29e6de  D29ESP32DE3BC5A
# 6   TANGARA_BCC6  d29e6de  D29ESP32DE3BCC6
# 7   TANGARA_BD5E  d29e6de  D29ESP32DE3BD5E
# 8   TANGARA_BE12  d29e6de  D29ESP32DE3BE12
# 9   TANGARA_2BDE  d29efb4  D29ESP32DE52BDE
# 10  TANGARA_3B7E  d29ee40  D29ESP32DE53B7E
# 11  TANGARA_421A  d29egkt  D29ESP32DE5421A
# 12  TANGARA_79CA  d29e6de  D29ESP32DE679CA
# 13  TANGARA_1402  d29e6de  D29ESP32DE71402
# 14  TANGARA_157E  d29e6de  D29ESP32DE7157E
# 15  TANGARA_1DE2  d29e6de  D29ESP32DE71DE2
# 16  TANGARA_298A  d29e6de  D29ESP32DE7298A
# 17  TANGARA_3376  d29e6de  D29ESP32DE73376
# 18  TANGARA_5636  d29e7tv  D29ESP32DE85636
# 19  TANGARA_D282  d29e6fj  D29ESP32DE8D282
# 20  TANGARA_4B1A  d29esj8  D29ESP32DE94B1A
# 21  TANGARA_1106  d29edzu  D29ESP32DEC1106
# 22  TANGARA_1282  d29edvt  D29ESP32DED1282
# 23  TANGARA_14D6  d29eg4k  D29ESP32DED14D6
# 24  TANGARA_1A1E  d29e7qm  D29ESP32DED1A1E
# 25  TANGARA_2492  d29e4y4  D29ESP32DED2492
# 26  TANGARA_2E9A  d29ed62  D29ESP32DED2E9A
# 27  TANGARA_2FF6  d29e66v  D29ESP32DED2FF6
# 28  TANGARA_307A  d29e48s  D29ESP32DED307A
# 29  TANGARA_3782  d29eddn  D29ESP32DED3782
# 30  TANGARA_F212  d29ed9s  D29ESP32DEDF212
# 31  TANGARA_1712  d29dfx4  D29ESP32DEE1712
# 32  TANGARA_A43A  d29e6de  D29ESP32DEFA43A
# 33  TANGARA_C17E  d29e6de  D29ESP32DEFC17E
# 34  TANGARA_CA62  d29e6de  D29ESP32DEFCA62
# 35  TANGARA_532E  d29ed74   D29TTGOT7D532E
# 36  TANGARA_F1AE  d29eg69   D29TTGOTD8F1AE
# 37  TANGARA_06BE  d29e6de   D29TTGOTD906BE
#
#                               GEOLOCATION  LATITUDE  LONGITUDE
# 0   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 1   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 2   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 3   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 4   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 5   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 6   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 7   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 8   3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 9   3.4723663330078125 -76.51634216308594  3.472366 -76.516342
# 10  3.4394073486328125 -76.50810241699219  3.439407 -76.508102
# 11  3.4970855712890625 -76.49024963378906  3.497086 -76.490250
# 12  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 13  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 14  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 15  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 16  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 17  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 18  3.4160614013671875 -76.47926330566406  3.416061 -76.479263
# 19  3.3954620361328125 -76.51222229003906  3.395462 -76.512222
# 20  3.4586334228515625 -76.46415710449219  3.458633 -76.464157
# 21  3.4709930419921875 -76.51359558105469  3.470993 -76.513596
# 22  3.4586334228515625 -76.51222229003906  3.458633 -76.512222
# 23  3.4847259521484375 -76.50260925292969  3.484726 -76.502609
# 24  3.4188079833984375 -76.49024963378906  3.418808 -76.490250
# 25  3.3734893798828125 -76.51634216308594  3.373489 -76.516342
# 26  3.4407806396484375 -76.54106140136719  3.440781 -76.541061
# 27  3.3995819091796875 -76.53419494628906  3.399582 -76.534195
# 28  3.3432769775390625 -76.52458190917969  3.343277 -76.524582
# 29  3.4394073486328125 -76.52183532714844  3.439407 -76.521835
# 30  3.4366607666015625 -76.52458190917969  3.436661 -76.524582
# 31  3.3350372314453125 -76.52732849121094  3.335037 -76.527328
# 32  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 33  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 34  3.3982086181640625 -76.52595520019531  3.398209 -76.525955
# 35  3.4449005126953125 -76.53831481933594  3.444901 -76.538315
# 36  3.4860992431640625 -76.49574279785156  3.486099 -76.495743
# 37  3.3982086181640625 -76.52595520019531  3.398209 -76.525955

# %% [markdown]
# ## Temperature Raw Data

# %%
# Start Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
start_timestamp = to_timestamp(START_ISO8601_DATETIME)
# End Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
end_timestamp = to_timestamp(os.getenv("END_ISO8601_DATETIME", None))

# GROUP BY TIME
GROUP_BY_TIME = os.getenv("GROUP_BY_TIME", None)

print(f'Since: {START_ISO8601_DATETIME} -> {start_timestamp}, Until: {END_ISO8601_DATETIME} -> {end_timestamp}')
print(f"Group by Time: {GROUP_BY_TIME}")
# Out:
# 2024-09-20 18:20:52.122 | DEBUG    | utils:to_timestamp:79 - Run to_timestamp:
# 2024-09-20 18:20:52.123 | DEBUG    | utils:to_timestamp:80 - datetime_iso8601: 2024-08-01T00:00:00-05:00, Timestamp: 1722488400000
# 2024-09-20 18:20:52.123 | DEBUG    | utils:to_timestamp:79 - Run to_timestamp:
# 2024-09-20 18:20:52.123 | DEBUG    | utils:to_timestamp:80 - datetime_iso8601: 2024-08-31T23:59:59-05:00, Timestamp: 1725166799000
# Since: 2024-08-01T00:00:00-05:00 -> 1722488400000, Until: 2024-08-31T23:59:59-05:00 -> 1725166799000
# Group by Time: 30s

# %%
# Temperature Data Frame Sensors
df_temp_raw = df_data_sensors(df_tangaras, start_timestamp, end_timestamp, 'tmp', GROUP_BY_TIME)
df_temp_raw.shape
# Out:
# 2024-09-20 18:20:52.128 | DEBUG    | utils:query_measure:193 - Run query_measure:
# 2024-09-20 18:20:52.129 | DEBUG    | utils:query_measure:194 - sql_query: SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE0B7BE') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE0C752') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3A682') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3ADD6') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3B9CA') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3BC5A') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3BCC6') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3BD5E') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3BE12') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE52BDE') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE53B7E') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE5421A') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE679CA') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE71402') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE7157E') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE71DE2') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE7298A') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE73376') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE85636') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE8D282') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE94B1A') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DEC1106') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DED1282') AND time >= 1722488400000ms AND time <= 1725166799000ms GROUP BY time(30s) fill(null); SELECT last("tmp") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DED14D6') AND time >= 1722488400000ms A ...
# 2024-09-20 18:21:30.727 | DEBUG    | utils:request_influxdb:118 - Run request_influxdb:
# 2024-09-20 18:21:30.728 | DEBUG    | utils:request_influxdb:119 - response: <Response [200]>
# /home/sebaxtian/Workspaces/Tangara/tangara-mlds-unal-2024/src/tangara/notebooks/utils.ipynb:411: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df_sensors = df_sensors.asfreq(freq=group_by_time)
# 2024-09-20 18:21:32.593 | DEBUG    | utils:df_data_sensors:419 - Run df_data_sensors:
# 2024-09-20 18:21:32.594 | DEBUG    | utils:df_data_sensors:420 - Measure Data Frame Sensors: <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 89280 entries, 2024-08-01 00:00:00-05:00 to 2024-08-31 23:59:30-05:00
# Freq: 30s
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TANGARA_B7BE  67718 non-null  float64
#  1   TANGARA_C752  48966 non-null  float64
#  2   TANGARA_A682  85089 non-null  float64
#  3   TANGARA_ADD6  64851 non-null  float64
#  4   TANGARA_B9CA  72173 non-null  float64
#  5   TANGARA_BC5A  88271 non-null  float64
#  6   TANGARA_BCC6  72479 non-null  float64
#  7   TANGARA_BD5E  48948 non-null  float64
#  8   TANGARA_BE12  48922 non-null  float64
#  9   TANGARA_2BDE  85978 non-null  float64
#  10  TANGARA_3B7E  47921 non-null  float64
#  11  TANGARA_421A  34281 non-null  float64
#  12  TANGARA_79CA  62526 non-null  float64
#  13  TANGARA_1402  72524 non-null  float64
#  14  TANGARA_157E  65778 non-null  float64
#  15  TANGARA_1DE2  72288 non-null  float64
#  16  TANGARA_298A  88393 non-null  float64
#  17  TANGARA_3376  88215 non-null  float64
#  18  TANGARA_5636  67862 non-null  float64
#  19  TANGARA_D282  39338 non-null  float64
#  20  TANGARA_4B1A  18174 non-null  float64
#  21  TANGARA_1106  87592 non-null  float64
#  22  TANGARA_1282  54523 non-null  float64
#  23  TANGARA_14D6  85874 non-null  float64
#  24  TANGARA_1A1E  87122 non-null  float64
#  25  TANGARA_2492  69703 non-null  float64
# dtypes: float64(26)
# memory usage: 18.4 MB
# (89280, 26)

# %%
df_temp_raw
# Out:
#                            TANGARA_B7BE  TANGARA_C752  TANGARA_A682  \
# DATETIME
# 2024-08-01 00:00:00-05:00         31.39           NaN         31.49
# 2024-08-01 00:00:30-05:00         31.38           NaN         31.48
# 2024-08-01 00:01:00-05:00         31.44           NaN         31.51
# 2024-08-01 00:01:30-05:00         31.45           NaN         31.49
# 2024-08-01 00:02:00-05:00         31.44           NaN         31.48
# ...                                 ...           ...           ...
# 2024-08-31 23:57:30-05:00           NaN         31.92           NaN
# 2024-08-31 23:58:00-05:00           NaN         31.90           NaN
# 2024-08-31 23:58:30-05:00           NaN         31.90           NaN
# 2024-08-31 23:59:00-05:00           NaN         31.92           NaN
# 2024-08-31 23:59:30-05:00           NaN         31.92           NaN
#
#                            TANGARA_ADD6  TANGARA_B9CA  TANGARA_BC5A  \
# DATETIME
# 2024-08-01 00:00:00-05:00         31.73         33.61         32.37
# 2024-08-01 00:00:30-05:00         31.72         33.57         32.38
# 2024-08-01 00:01:00-05:00         31.73         33.58         32.35
# 2024-08-01 00:01:30-05:00         31.76         33.57         32.37
# 2024-08-01 00:02:00-05:00         31.73         33.57         32.30
# ...                                 ...           ...           ...
# 2024-08-31 23:57:30-05:00         25.85         35.21         31.75
# 2024-08-31 23:58:00-05:00         25.85         35.21         31.76
# 2024-08-31 23:58:30-05:00         25.82         35.21         31.76
# 2024-08-31 23:59:00-05:00         25.81         35.19         31.77
# 2024-08-31 23:59:30-05:00         25.82         35.18         31.75
#
#                            TANGARA_BCC6  TANGARA_BD5E  TANGARA_BE12  \
# DATETIME
# 2024-08-01 00:00:00-05:00         34.20           NaN           NaN
# 2024-08-01 00:00:30-05:00         34.17           NaN           NaN
# 2024-08-01 00:01:00-05:00         34.19           NaN           NaN
# 2024-08-01 00:01:30-05:00         34.15           NaN           NaN
# 2024-08-01 00:02:00-05:00         34.13           NaN           NaN
# ...                                 ...           ...           ...
# 2024-08-31 23:57:30-05:00         32.18         31.30         31.73
# 2024-08-31 23:58:00-05:00         32.17         31.30         31.73
# 2024-08-31 23:58:30-05:00         32.17         31.27         31.73
# 2024-08-31 23:59:00-05:00         32.15         31.30         31.76
# 2024-08-31 23:59:30-05:00         32.17         31.30         31.74
#
#                            TANGARA_2BDE  ...  TANGARA_298A  TANGARA_3376  \
# DATETIME                                 ...
# 2024-08-01 00:00:00-05:00           NaN  ...         34.37         31.22
# 2024-08-01 00:00:30-05:00         29.45  ...         34.35         31.29
# 2024-08-01 00:01:00-05:00         29.41  ...         34.37         31.32
# 2024-08-01 00:01:30-05:00         29.35  ...         34.29         31.34
# 2024-08-01 00:02:00-05:00         29.34  ...         34.32         31.37
# ...                                 ...  ...           ...           ...
# 2024-08-31 23:57:30-05:00         28.04  ...         32.23         29.58
# 2024-08-31 23:58:00-05:00         28.01  ...         32.23         29.57
# 2024-08-31 23:58:30-05:00         27.98  ...         32.19         29.55
# 2024-08-31 23:59:00-05:00           NaN  ...         32.21         29.62
# 2024-08-31 23:59:30-05:00           NaN  ...         32.21         29.61
#
#                            TANGARA_5636  TANGARA_D282  TANGARA_4B1A  \
# DATETIME
# 2024-08-01 00:00:00-05:00           NaN           NaN         27.33
# 2024-08-01 00:00:30-05:00         28.53         29.41         27.33
# 2024-08-01 00:01:00-05:00         28.49         29.35         27.31
# 2024-08-01 00:01:30-05:00         28.47         29.33         27.29
# 2024-08-01 00:02:00-05:00         28.44         29.28         27.27
# ...                                 ...           ...           ...
# 2024-08-31 23:57:30-05:00         26.86           NaN           NaN
# 2024-08-31 23:58:00-05:00         26.88           NaN           NaN
# 2024-08-31 23:58:30-05:00         26.90           NaN           NaN
# 2024-08-31 23:59:00-05:00           NaN           NaN           NaN
# 2024-08-31 23:59:30-05:00           NaN           NaN           NaN
#
#                            TANGARA_1106  TANGARA_1282  TANGARA_14D6  \
# DATETIME
# 2024-08-01 00:00:00-05:00           NaN           NaN           NaN
# 2024-08-01 00:00:30-05:00         30.15         29.18         28.98
# 2024-08-01 00:01:00-05:00         30.14         29.18         28.95
# 2024-08-01 00:01:30-05:00         30.11         29.18         28.91
# 2024-08-01 00:02:00-05:00         30.11         29.15         28.88
# ...                                 ...           ...           ...
# 2024-08-31 23:57:30-05:00         29.13           NaN         28.51
# 2024-08-31 23:58:00-05:00         29.16           NaN         28.51
# 2024-08-31 23:58:30-05:00         29.13           NaN         28.49
# 2024-08-31 23:59:00-05:00           NaN           NaN           NaN
# 2024-08-31 23:59:30-05:00           NaN           NaN           NaN
#
#                            TANGARA_1A1E  TANGARA_2492
# DATETIME
# 2024-08-01 00:00:00-05:00         28.01           NaN
# 2024-08-01 00:00:30-05:00         27.99         31.24
# 2024-08-01 00:01:00-05:00         27.98         31.26
# 2024-08-01 00:01:30-05:00         27.96         31.26
# 2024-08-01 00:02:00-05:00         27.98         31.26
# ...                                 ...           ...
# 2024-08-31 23:57:30-05:00         27.77         29.85
# 2024-08-31 23:58:00-05:00         27.58         29.86
# 2024-08-31 23:58:30-05:00         27.46         29.86
# 2024-08-31 23:59:00-05:00         27.61           NaN
# 2024-08-31 23:59:30-05:00         27.41           NaN
#
# [89280 rows x 26 columns]

# %%
file_name = to_file_name("temp_raw", START_ISO8601_DATETIME, END_ISO8601_DATETIME)
file_name
# Out:
# 2024-09-20 18:21:32.627 | DEBUG    | utils:to_file_name:448 - Run to_file_name:
# 2024-09-20 18:21:32.628 | DEBUG    | utils:to_file_name:449 - File Name: temp_raw_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv
# 'temp_raw_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv'

# %%
# Save Temperature Data Frame Sensors into CSV file
df_to_csv(df_temp_raw, file_name)
# Out:
# 2024-09-20 18:21:33.506 | DEBUG    | utils:df_to_csv:228 - Run df_to_csv:
# 2024-09-20 18:21:33.507 | DEBUG    | utils:df_to_csv:229 - Save DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-mlds-unal-2024/src/tangara/data/0_raw/temp_raw_2024-08-01_00-00-00_UTC-0500_2024-08-31_23-59-59_UTC-0500.csv

# %%
df_temp_raw.shape
# Out:
# (89280, 26)
